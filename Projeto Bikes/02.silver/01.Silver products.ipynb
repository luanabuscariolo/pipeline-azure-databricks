# %% [markdown]
# %md
# Criar uma tabela de produtos já unindo categoria,marca (brands)<br> e quantidade total  de estoque em todas as lojas

# %%
bronze_path   = 'abfss://data@datalakedatabrickstest.dfs.core.windows.net/bikestore/bronze/'
silver_path   = 'abfss://data@datalakedatabrickstest.dfs.core.windows.net/bikestore/silver/'
gold_path     = 'abfss://data@datalakedatabrickstest.dfs.core.windows.net/bikestore/gold/'
resource_path = 'abfss://data@datalakedatabrickstest.dfs.core.windows.net/bikestore/resource/origem/'
resource_path_volume = '/Volumes/bikestore/logistics/bikestore_resource/origem/'

# %%
bronze_map = {
    "tmp_bronze_brands":      f"{bronze_path}/brands/",
    "tmp_bronze_categories":  f"{bronze_path}/categories/",
    "tmp_bronze_customers":   f"{bronze_path}/customers/",
    "tmp_bronze_order_items": f"{bronze_path}/order_items/",
    "tmp_bronze_orders":      f"{bronze_path}/orders/",
    "tmp_bronze_products":    f"{bronze_path}/products/",
    "tmp_bronze_staffs":      f"{bronze_path}/staffs/",
    "tmp_bronze_stocks":      f"{bronze_path}/stocks/",
    "tmp_bronze_stores":      f"{bronze_path}/stores/",
}
for view_name, path in bronze_map.items():
    (spark.read.format('delta')
        .load(path)
        .createOrReplaceTempView(view_name))

# %%
# %sql
select * from tmp_bronze_brands

# %%
# %sql
describe tmp_bronze_brands

# %%
# %sql
-- consulta principal
with
stock as ( 
select 
  product_id
  ,sum(quantity) as total_stock
from tmp_bronze_stocks
--where product_id = 1
group by product_id
)


select
   p.product_id
  ,p.product_name
  --,p.brand_id
  --,b.brand_id as brand_id_brand
  ,b.brand_name
  --,p.category_id
  --,c.category_id as category_id_categoriat
  ,c.category_name
  ,p.model_year
  ,p.list_price
  ,s.total_stock
from        tmp_bronze_products as p
left join tmp_bronze_categories as c on p.category_id = c.category_id
left join     tmp_bronze_brands as b on p.brand_id = b.brand_id
left join                 stock as s on p.product_id = s.product_id

# %%
# %sql
-- soma de estoque em todas lojas CTE (Common Table Expression) é um “bloco temporário de consulta” dentro do SQL
--- exemplo CTE
with
stock as ( 
select 
  product_id
  ,sum(quantity) as total_stock
from tmp_bronze_stocks
where product_id = 1
group by product_id
) 
select * from stock

# %%
df_product_silver = spark.sql("""
with
stock as ( 
select 
  product_id
  ,sum(quantity) as total_stock
from tmp_bronze_stocks
--where product_id = 1
group by product_id
)


select
   p.product_id
  ,p.product_name
  --,p.brand_id
  --,b.brand_id as brand_id_brand
  ,b.brand_name
  --,p.category_id
  --,c.category_id as category_id_categoriat
  ,c.category_name
  ,p.model_year
  ,p.list_price
  ,s.total_stock
from        tmp_bronze_products as p
left join tmp_bronze_categories as c on p.category_id = c.category_id
left join     tmp_bronze_brands as b on p.brand_id = b.brand_id
left join                 stock as s on p.product_id = s.product_id                             
                              
                              
                              """)

# salvar em Delta na silver 
df_product_silver.write\
    .mode('overwrite')\
    .format('delta')\
    .option('mergeSchema','true')\
    .save(f'{silver_path}/product')

# %%
display(df_product_silver)

# %%
# %sql
/*Criar tabela fisica Eeste comando prescisa rodar só 1x pois quando arquivos forem atualizados a tabela irá refletir o resultado  (irá pegar o log mais recente e trazer dados do arquivo(os) atualizados)*/
CREATE TABLE IF NOT EXISTS bikestore.logistics.silver_products
LOCATION 'abfss://data@datalakedatabrickstest.dfs.core.windows.net/bikestore/silver/product';

# %%
# %sql
select * from bikestore.logistics.silver_products limit 15
